# %% [markdown]
# # EDA
# # Exploratory Data Analysis
#
# ## Key Components
# #### * Summary Statistics
# #### * Data Visualization
# #### * Handling Missing Data
# #### * Data Transformation
# #### * Feature Engineering

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df=sns.load_dataset('titanic')

# %%
df.to_csv("titanic.csv")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Understanding Data

# %%
df.sample(5)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 783         0       3  male   NaN      1      2  23.4500        S   Third
# 785         0       3  male  25.0      0      0   7.2500        S   Third
# 709         1       3  male   NaN      1      1  15.2458        C   Third
# 382         0       3  male  32.0      0      0   7.9250        S   Third
# 685         0       2  male  25.0      1      2  41.5792        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 783  man        True  NaN  Southampton    no  False
# 785  man        True  NaN  Southampton    no   True
# 709  man        True  NaN    Cherbourg   yes  False
# 382  man        True  NaN  Southampton    no   True
# 685  man        True  NaN    Cherbourg    no  False

# %%
df.shape
# Out:
# (891, 15)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# ### Categorical Data
# * survived
# * pclass
# * sex
# * sibsp
# * parch
# * categorical
# * class
# * who
# * adult_male
#
# ### Numerical
# * age
# * numerical

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ## Checking null values

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # Checking the unique values

# %%
print(df["embark_town"].unique())
print(df["embarked"].unique())
print(df["sex"].unique())
print(df["sibsp"].unique())
print(df["parch"].unique())
print(df["pclass"].unique())
print(df["survived"].unique())
print(df["class"].unique())
print(df["who"].unique())
print(df["adult_male"].unique())
print(df["alive"].unique())
print(df["alone"].unique())
print(df["deck"].unique())
# Out:
# ['Southampton' 'Cherbourg' 'Queenstown' nan]
# ['S' 'C' 'Q' nan]
# ['male' 'female']
# [1 0 3 4 2 5 8]
# [0 1 2 5 3 4 6]
# [3 1 2]
# [0 1]
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']
# ['man' 'woman' 'child']
# [ True False]
# ['no' 'yes']
# [False  True]
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %% [markdown]
# # Checking the value count of unique values

# %%
print(df["sex"].value_counts())
print("\n")
print(df["embarked"].value_counts())
print("\n")
print(df["parch"].value_counts())
print("\n")
print(df["survived"].value_counts())
print("\n")
print(df["sibsp"].value_counts())
print("\n")
print(df["pclass"].value_counts())
print("\n")
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64
#
#
# embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64
#
#
# parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64
#
#
# survived
# 0    549
# 1    342
# Name: count, dtype: int64
#
#
# sibsp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64
#
#
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.drop(columns=["deck"], inplace = True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.drop(columns=["alive"], inplace = True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town  alone
# ...

# %%
df.drop(columns=["embark_town"], inplace = True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  alone
# ...

# %% [markdown]
# # Question?
#
# # Can we drop any more columns?
# ## Without affecting the dataset

# %%
df.drop(columns=["class"], inplace = True)
df.drop(columns=["sex"], inplace = True)

# %%
df
# Out:
#      survived  pclass   age  sibsp  parch     fare embarked    who  \
# 0           0       3  22.0      1      0   7.2500        S    man
# 1           1       1  38.0      1      0  71.2833        C  woman
# 2           1       3  26.0      0      0   7.9250        S  woman
# 3           1       1  35.0      1      0  53.1000        S  woman
# 4           0       3  35.0      0      0   8.0500        S    man
# ..        ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2  27.0      0      0  13.0000        S    man
# 887         1       1  19.0      0      0  30.0000        S  woman
# 888         0       3   NaN      1      2  23.4500        S  woman
# 889         1       1  26.0      0      0  30.0000        C    man
# 890         0       3  32.0      0      0   7.7500        Q    man
#
#      adult_male  alone
# 0          True  False
# 1         False  False
# 2         False   True
# 3         False  False
# 4          True   True
# ...

# %%
df.isna().sum()
# Out:
# survived        0
# pclass          0
# age           177
# sibsp           0
# parch           0
# fare            0
# embarked        2
# who             0
# adult_male      0
# alone           0
# dtype: int64

# %%
df.drop(columns=["deck"], inplace = True)
df.drop(columns=["embark_town"], inplace = True)
df.drop(columns=["alive"], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df.drop(columns=["deck"], inplace = True)
#       2 df.drop(columns=["embark_town"], inplace = True)
#       3 df.drop(columns=["alive"], inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
# ...

# %% [markdown]
# # Filling null values

# %%
df['embarked'].fillna('S',inplace=True)

# %%
df['age'].fillna(df['age'].mean(),inplace=True)

# %%
df
# Out:
#      survived  pclass        age  sibsp  parch     fare embarked    who  \
# 0           0       3  22.000000      1      0   7.2500        S    man
# 1           1       1  38.000000      1      0  71.2833        C  woman
# 2           1       3  26.000000      0      0   7.9250        S  woman
# 3           1       1  35.000000      1      0  53.1000        S  woman
# 4           0       3  35.000000      0      0   8.0500        S    man
# ..        ...     ...        ...    ...    ...      ...      ...    ...
# 886         0       2  27.000000      0      0  13.0000        S    man
# 887         1       1  19.000000      0      0  30.0000        S  woman
# 888         0       3  29.699118      1      2  23.4500        S  woman
# 889         1       1  26.000000      0      0  30.0000        C    man
# 890         0       3  32.000000      0      0   7.7500        Q    man
#
#      adult_male  alone
# 0          True  False
# 1         False  False
# 2         False   True
# ...

# %%
df.isna().sum()
# Out:
# survived      0
# pclass        0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# who           0
# adult_male    0
# alone         0
# dtype: int64

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # Conclusions
#
# In the dataset:
# * 38.38% survived
# * most people were in 3rd class
# * 50% passengers between age of 20 to 35

# %%
# Select only numeric columns for correlation calculation
numeric_columns = df.select_dtypes(include=['number'])
correlation_matrix = numeric_columns.corr()
correlation_matrix
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.069809 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.331339  0.083081  0.018443 -0.549500
# age      -0.069809 -0.331339  1.000000 -0.232625 -0.179191  0.091566
# sibsp    -0.035322  0.083081 -0.232625  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.179191  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.091566  0.159651  0.216225  1.000000

# %% [markdown]
# See there is positive correlation between Survived and Fare, this make sense cause that more rich passanger were survived.
# and there is negative correlataion between Survived and Pclass, as the passenger class increases for first to second to third they were more likely to not survived.

# %%
sns.countplot(x = "survived", data=df)
print('No of people survived are',round(df['survived'].value_counts().values[0]*100/891),'%')
# Out:
# No of people survived are 62 %

# %%
df[df['who'] == 'man'].survived.groupby(df.survived).count().plot(kind='pie', figsize=(6, 6),explode=[0,0.05],autopct='%1.1f%%')
plt.axis('equal')
plt.legend(["Perished","Survived"])
plt.title("Male survival rate")
plt.show()

df[df['who'] == 'woman'].survived.groupby(df.survived).count().plot(kind='pie', figsize=(6, 6),explode=[0,0.05],autopct='%1.1f%%')
plt.axis('equal')
plt.legend(["Perished","Survived"])
plt.title("Female survival rate")
plt.show()

# %%
df[df['pclass'] == 1].survived.groupby(df.survived).count().plot(kind='pie', figsize=(6, 6),explode=[0,0.05],autopct='%1.1f%%')
plt.axis('equal')
plt.legend(["Perished","Survived"])
plt.title("1st class survival rate")
plt.show()

df[df['pclass'] == 2].survived.groupby(df.survived).count().plot(kind='pie', figsize=(6, 6),explode=[0,0.05],autopct='%1.1f%%')
plt.axis('equal')
plt.legend(["Perished","Survived"])
plt.title("2nd class survival rate")
plt.show()

df[df['pclass'] == 3].survived.groupby(df.survived).count().plot(kind='pie', figsize=(6, 6),explode=[0,0.05],autopct='%1.1f%%')
plt.axis('equal')
plt.legend(["Perished","Survived"])
plt.title("3rd class survival rate")
plt.show()

# %%
age_died = df[(df["age"] > 0) & 
                              (df["survived"] == 0)]
age_surv = df[(df["age"] > 0) & 
                              (df["survived"] == 1)]

#figure size
plt.figure(figsize=(10,5))

# Ploting the 2 variables that we create and compare the two
sns.distplot(age_surv["age"], color='g')
sns.distplot(age_died["age"], color='r')
plt.title("Distribuition and density by Age",fontsize=20)
plt.xlabel("Age",fontsize=15)
plt.ylabel("Distribuition Died and Survived",fontsize=15)
plt.show()
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_21780\2771114101.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age_surv["age"], color='g')
# C:\Users\prash\AppData\Local\Temp\ipykernel_21780\2771114101.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare embarked    who  adult_male  \
# 0         0       3  22.0      1      0   7.2500        S    man        True
# 1         1       1  38.0      1      0  71.2833        C  woman       False
# 2         1       3  26.0      0      0   7.9250        S  woman       False
# 3         1       1  35.0      1      0  53.1000        S  woman       False
# 4         0       3  35.0      0      0   8.0500        S    man        True
#
#    alone
# 0  False
# 1  False
# 2   True
# 3  False
# 4   True

# %%
survived_sex_counts = df.groupby(['survived', 'who']).size().unstack()
survived_sex_counts.plot(kind='bar', stacked=True)
plt.xlabel('Survived')
plt.ylabel('Count')
plt.title('Survival Count by Sex')

# Show the plot
plt.show()

# %%
df.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare embarked    who  adult_male  \
# 0         0       3  22.0      1      0   7.2500        S    man        True
# 1         1       1  38.0      1      0  71.2833        C  woman       False
# 2         1       3  26.0      0      0   7.9250        S  woman       False
# 3         1       1  35.0      1      0  53.1000        S  woman       False
# 4         0       3  35.0      0      0   8.0500        S    man        True
#
#    alone
# 0  False
# 1  False
# 2   True
# 3  False
# 4   True

# %%
# Count the number of females who survived
num_females_survived = df[(df["who"] == "woman") & (df["survived"] == 1)].shape[0]
num_males_survived = df[(df["who"] == "man") & (df["survived"] == 1)].shape[0]


print("Number of females who survived:", num_females_survived)
print("Number of females who survived:", num_males_survived)
# Out:
# Number of females who survived: 205
# Number of females who survived: 88

# %%
df['survived']=df['survived'].astype('category')
df['pclass']=df['pclass'].astype('category')
df['who']=df['who'].astype('category')
df['age']=df['age'].astype('int')
df['embarked']=df['embarked'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    category
#  1   pclass      891 non-null    category
#  2   age         891 non-null    int32
#  3   sibsp       891 non-null    int64
#  4   parch       891 non-null    int64
#  5   fare        891 non-null    float64
#  6   embarked    891 non-null    category
#  7   who         891 non-null    category
#  8   adult_male  891 non-null    bool
#  9   alone       891 non-null    bool
# dtypes: bool(2), category(4), float64(1), int32(1), int64(2)
# memory usage: 30.2 KB

# %%
sns.pairplot(df)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\prash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
